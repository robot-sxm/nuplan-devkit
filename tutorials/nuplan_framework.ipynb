# %% [markdown]
# ![](https://www.nuplan.org/static/media/nuPlan_final.3fde7586.png)

# %% [markdown]
# ### Contents
#
# 1. [Introduction to nuPlan](#introduction)
# 2. [Training an ML planner](#training)
# 3. [Simulating a planner](#simulation)
# 4. [Visualizing metrics and scenarios](#dashboard)

# %%
from tutorials.utils.tutorial_utils import setup_notebook

setup_notebook()

import os
NUPLAN_DATA_ROOT = os.getenv('NUPLAN_DATA_ROOT', '~/nuplan')
NUPLAN_MAPS_ROOT = os.getenv('NUPLAN_MAPS_ROOT', '~/nuplan/dataset/maps')
NUPLAN_DB_FILES = os.getenv('NUPLAN_DB_FILES', '~/nuplan/dataset/nuplan-v1.1/splits/mini')
NUPLAN_MAP_VERSION = os.getenv('NUPLAN_MAP_VERSION', 'nuplan-maps-v1.0')

# %% [markdown]
# # Introduction to nuPlan <a name="introduction"></a>

# %% [markdown]
# Welcome to nuPlan! This notebook will explore the nuPlan simulation framework, training platform as well as the nuBoard metrics/scenarios visualization dashboard.

# %% [markdown]
# ## What is nuPlan
#
# nuPlan is the world’s first closed-loop ML-based planning benchmark for autonomous driving.
#
# It provides a high quality dataset with 1500h of human driving data from 4 cities across the US and Asia with widely varying traffic patterns (Boston, Pittsburgh, Las Vegas and Singapore). In addition, it provides a closed-loop simulation framework with reactive agents, a training platform as well as a large set of both general and scenario-specific planning metrics.
#
# ![](https://www.nuscenes.org/static/media/framework_steps.2d4642df.png)

# %% [markdown]
# ## Training & simulation framework
#
# The nuPlan training and simulation framework aims to:
# * create a simulation pipeline to evaluate a planner on large dataset with various scenarios
# * score planner performance with common and scenario-dependent metrics
# * compare planners based on measured metrics and provide intuitive visualizations
# * train planners with the provided framework to allow quick implementation and iteration
# * support closed-loop simulation and training
#
# <br />
#
# ![](https://www.nuplan.org/static/media/planning_framework.ca3c2969.png)

# %% [markdown]
# ## Scenarios in nuPlan
#
# nuPlan aims to capture challenging yet representative scenarios from real-world encounters. This enables the benchmarking of planning systems both in expert imitation (open-loop) and reactive planning (closed-loop) settings.
#
# These scenarios includes:
# * highly interactive scenes with traffic participants (e.g. tailgating, high-velocity overtakes, double parked cars, jaywalking)
# * various ego behaviors (e.g. vehicle following, yielding, lane merging) and dynamics (e.g. mixed speed profiles, abrupt braking, speed bumps, high jerk maneuvers)
# * scene layouts of varied complexity (e.g. pudos, traffic/stop controlled intersections, unprotected turns) and temporary zones (e.g. construction areas)
#
# The dataset is automatically tagged with scenario labels based on certain primitive attributes.
# These scenario tags can then be used to extract representative metrics for the planner's evaluation.
#
# Example mined scenarios in nuPlan:
#
# | | | |
# | :-: | :-: | :-: |
# | Unprotected cross turn | Dense vehicle interactions | Jaywalker in front |
# | ![](https://www.nuscenes.org/static/media/unprotected-cross.51feef7e.webp) | ![](https://www.nuscenes.org/static/media/dense-interactions.16de47ec.webp) | ![](https://www.nuscenes.org/static/media/jaywalker.03083823.webp) |
# | Lane change | Ego at pickup/dropoff area | Ego following vehicle |
# | ![](https://www.nuscenes.org/static/media/lane-change.54bfca1c.webp) | ![](https://www.nuscenes.org/static/media/pickup-dropoff.4dd1c418.webp) | ![](https://www.nuscenes.org/static/media/following-vehicle.4cacd559.webp) |

# %% [markdown]
# ## Database
#
# Download a database for training/simulation from [here](https://nuplan.org/nuplan#download).
#
# | Database | Size | Duration | Num Logs | Cities | Num Scenarios | Sensor Data | Description |
# | :-- | :-- | :-- | :-- | :-- | :-- | :-- | :-- |
# | nuplan_v1.1_mini (recommended) | 13GB | 7h | 64 | Las Vegas, Boston, Pittsburgh, Singapore | 67 | N/A | The mini split used for prototyping and testing |
# | nuplan_v1.1 | 1.8TB | 1282h | 15910 | Las Vegas, Boston, Pittsburgh, Singapore | 73 | N/A | The full dataset for training and evaluation|

# %% [markdown]
# ## Setup
#
# To be able to access all resources within this notebook, make sure Jupyter is launched at the root of this repo. The path of the notebook should be `/notebook/<repo_root>`.

# %%
# (Optional) Increase notebook width for all embedded cells to display properly
from IPython.core.display import display, HTML
display(HTML("<style>.output_result { max-width:100% !important; }</style>"))
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /tmp/ipykernel_32027/4180358289.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.output_result { max-width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>

# %%
# Useful imports
import os
from pathlib import Path
import tempfile

import hydra

# %% [markdown]
# # Training an ML planner <a name="training"></a>

# %% [markdown]
# ## Imitation learning
# In the following section we will train an ML planning policy with the aim estimate the ego's future trajectory and control the vehicle.
#
# The policy is learned through imitation learning, a supervised learning approach in which - in the context of autonomous driving - the behavior of an expert human driver is used as a target signal to supervise the model.
#
# ## Model features & targets
# A planning policy consumes a set of episodic observations and encodes them through a deep neural network to regress a future trajectory.
#
# The observations can be historic or present ego and agent poses as well as static/dynamic map information across different map layers.<br />
# These signals can be encoded through various representations, such as raster or vector format for the map signal, each with their pros and cons for each model flavor.
#
# Using these input features the model predicts a discretized future trajectory across a fixed time horizon.<br />
# The trajectory consists of a set of discrete future states (position, heading and velocity) sampled at fixed intervals which express the likelihood of the vehicle being at that state in the future.<br />
# For example, a predicted trajectory may consist of 10 future poses sampled at intervals of 0.5s across a 5s horizon.
#
# ## Learning objectives
# The policy is trained to maximize a set of aggregated objectives such as imitation, collision avoidance, traffic rule violation etc.<br />
# Imitation is the core training objective which indicates how close the predicted trajectory is to the expert ground truth and penalizes model predictions that deviate in space and time from the demonstration.

# %% [markdown]
# ## Training parameters

# %% [markdown]
# The following parameter categories define the training protocol which includes the model, metrics, objectives etc.
#
# A working example composition of these parameters can be found in the next section.
#
# ---
#
# ### ML models
#
# Change the training model with `model=X` where `X` is a config yaml defined in the table below.
#
# | Model | Description | Config |
# | --- | --- | --- |
# | Raster model (CNN) | Raster-based model that uses a CNN backbone to encode ego, agent and map information as raster layers<br />Any (pretrained) backbone from the TIMM library can be used (e.g. ResNet50, EfficientNetB3) | `raster_model` |
# | Vector model (LaneGCN) | Vector-based model that uses a series of MLPs to encode ego and agent signals, a lane graph to encode vector-map elements and a fusion network to capture lane & agent intra/inter-interactions through attention layers<br />Implementation of LaneGCN paper ("Learning Lane Graph Representations for Motion Forecasting") | `vector_model` |
# | Simple vector model | Toy vector-based model that consumes ego, agent and lane signals through a series of MLPs | `simple_vector_model` |
#
# <br />
#
# ### Training objectives
#
# Change the training objectives with `objective=[X, ...]` where `X` is a config yaml defined in the table below.
#
# | Objective | Description | Config |
# | --- | --- | --- |
# | Imitation objective | Penalizes the predicted trajectory that deviates from the expert demonstration | `imitation_objective` |
#
# <br />
#
# ### Training metrics
#
# Change the training objectives with `training_metric=[X, ...]` where `X` is a config yaml defined in the table below.
#
# | Metric | Description | Config |
# | --- | --- | --- |
# | Average displacement error | RMSE translation error across full predicted trajectory | `avg_displacement_error` |
# | Average heading error | RMSE heading error across full predicted trajectory | `avg_heading_error` |
# | Final displacement error | L2 error of predicted trajectory's final pose translation | `final_displacement_error` |
# | Final heading error | L2 error of predicted trajectory's final pose heading | `final_heading_error` |

# %% [markdown]
# ## Prepare the training config

# %%
# Location of path with all training configs
CONFIG_PATH = '../nuplan/planning/script/config/training'
CONFIG_NAME = 'default_training'

# Create a temporary directory to store the cache and experiment artifacts
SAVE_DIR = Path(tempfile.gettempdir()) / 'tutorial_nuplan_framework'  # optionally replace with persistent dir
EXPERIMENT = 'training_raster_experiment'
JOB_NAME = 'train_default_raster'
LOG_DIR = SAVE_DIR / EXPERIMENT / JOB_NAME

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    f'group={str(SAVE_DIR)}',
    f'cache.cache_path={str(SAVE_DIR)}/cache',
    f'experiment_name={EXPERIMENT}',
    f'job_name={JOB_NAME}',
    'py_func=train',
    '+training=training_raster_model',  # raster model that consumes ego, agents and map raster layers and regresses the ego's trajectory
    'scenario_builder=nuplan_mini',  # use nuplan mini database
    'scenario_filter.limit_total_scenarios=1000',  # Choose 500 scenarios to train with
    'lightning.trainer.params.accelerator=ddp_spawn',  # ddp is not allowed in interactive environment, using ddp_spawn instead - this can bottleneck the data pipeline, it is recommended to run training outside the notebook
    'lightning.trainer.params.max_epochs=20',
    'data_loader.params.batch_size=10',
    'data_loader.params.num_workers=10',
])

# %% [markdown]
# ## Launch tensorboard for visualizing training artifacts

# %%
# %load_ext tensorboard
# %tensorboard --logdir {str(LOG_DIR)}
# Out:
#       <iframe id="tensorboard-frame-2339215f754b37bd" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-2339215f754b37bd");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Launch training (within the notebook)

# %%
# import os

# # 先清掉所有可能影响 httpx / huggingface_hub 的代理变量
# for key in list(os.environ.keys()):
#     if "proxy" in key.lower():
#         print("delete", key, os.environ[key])
#         del os.environ[key]

# # 如果你要走本地 SOCKS5 代理，再重新设置为 httpx 支持的 scheme
# proxy = "socks5://127.0.0.1:7897"

# os.environ["HTTP_PROXY"] = proxy
# os.environ["HTTPS_PROXY"] = proxy
# os.environ["ALL_PROXY"] = proxy
# os.environ["http_proxy"] = proxy
# os.environ["https_proxy"] = proxy
# os.environ["all_proxy"] = proxy

# # 检查：这里不应该再出现 socks://
# for key, value in os.environ.items():
#     if "proxy" in key.lower():
#         print(key, value)


from nuplan.planning.script.run_training import main as main_train

# Run the training loop, optionally inspect training artifacts through tensorboard (above cell)
main_train(cfg)
# Out:
# Global seed set to 0
# 2026-07-07 15:23:40,905 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:20}  Building experiment folders...
# 2026-07-07 15:23:40,905 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:22}  Experimental folder: /tmp/tutorial_nuplan_framework/training_raster_experiment/train_default_raster/2026.07.07.15.23.40
# 2026-07-07 15:23:40,906 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2026-07-07 15:23:40,907 INFO {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:78}  Starting ray local!
# 2026-07-07 15:23:42,680	INFO worker.py:1518 -- Started a local Ray instance.
# 2026-07-07 15:23:43,236 INFO {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2026-07-07 15:23:43,236 INFO {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 12
# Number of GPUs per node: 1
# Number of threads across all nodes: 12
# 2026-07-07 15:23:43,237 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2026-07-07 15:23:43,237 INFO {/root/nuplan-devkit/nuplan/planning/training/experiments/training.py:41}  Building training engine...
# 2026-07-07 15:23:43,237 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:23:43,758 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:23:43,817 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:23:43,837 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:23:43,837 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/splitter_builder.py:18}  Building Splitter...
# 2026-07-07 15:23:44,700 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/splitter_builder.py:21}  Building Splitter...DONE!
# 2026-07-07 15:23:44,701 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2026-07-07 15:23:44,714 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2026-07-07 15:23:44,714 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2026-07-07 15:23:44,716 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# Ray objects: 100%|████████████████████████████████████████████████████████████████████| 12/12 [00:03<00:00,  3.85it/s]
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# Using native 16bit precision.
# Global seed set to 0
# initializing ddp: GLOBAL_RANK: 0, MEMBER: 1/1
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All DDP processes registered. Starting ddp with 1 processes
# ----------------------------------------------------------------------------------------------------
# 2026-07-07 15:23:47,979 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_builder.py:171}  Extracted 1000 scenarios for training
# 2026-07-07 15:23:47,980 INFO {/root/nuplan-devkit/nuplan/planning/training/experiments/training.py:52}  Updating configs based on ddp_spawn strategy is currently not supported. Optimizer and LR Scheduler configs will not be updated.
# 2026-07-07 15:23:47,983 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/training_callback_builder.py:19}  Building callbacks...
# 2026-07-07 15:23:47,989 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/training_callback_builder.py:37}  Building callbacks...DONE!
# 2026-07-07 15:23:47,992 INFO {/root/nuplan-devkit/nuplan/planning/script/run_training.py:62}  Starting training...
# 2026-07-07 15:23:48,082 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:194}  Added key: store_based_barrier_key:1 to store for rank: 0
# 2026-07-07 15:23:48,083 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:224}  Rank 0: Completed store-based barrier for 1 nodes.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type        | Params
# --------------------------------------
# 0 | model | RasterModel | 23.6 M
# --------------------------------------
# 23.6 M    Trainable params
# 0         Non-trainable params
# 23.6 M    Total params
# 94.438    Total estimated model params size (MB)
# 2026-07-07 15:23:51,764 INFO {/root/nuplan-devkit/nuplan/planning/training/data_loader/datamodule.py:47}  Number of samples in train set: 654
# 2026-07-07 15:23:51,765 INFO {/root/nuplan-devkit/nuplan/planning/training/data_loader/datamodule.py:47}  Number of samples in validation set: 147
# 2026-07-07 15:23:51,768 INFO {/root/nuplan-devkit/nuplan/planning/training/modeling/lightning_module_wrapper.py:196}  Using optimizer: torch.optim.Adam
# 2026-07-07 15:23:51,768 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/lr_scheduler_builder.py:52}  Not using any lr_schedulers.
# /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/pytorch_lightning/trainer/data_loading.py:73: UserWarning: num_workers>0, persistent_workers=False, and accelerator=ddp_spawn may result in data loading bottlenecks. Consider setting persistent_workers=True (this is a limitation of Python .spawn() and PyTorch)
#   rank_zero_warn(
# /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/pytorch_lightning/callbacks/lr_monitor.py:97: RuntimeWarning: You are using `LearningRateMonitor` callback with models that have no learning rate schedulers. Please see documentation for `configure_optimizers` method.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# 2026-07-07 15:23:56,497 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/torch/nn/parallel/distributed.py:788}  Reducer buckets have been rebuilt in this iteration.
# /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/pytorch_lightning/trainer/callback_hook.py:100: LightningDeprecationWarning: The signature of `Callback.on_train_epoch_end` has changed in v1.3. `outputs` parameter has been removed. Support for the old signature will be removed in v1.5
#   warning_cache.deprecation(
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)

# %% [markdown]
# ## Launch training (command line - alternative)

# %% [markdown]
# A training experiment with the above same parameters can be launched alternatively with:
# ```
# $ python nuplan/planning/script/run_training.py \
#     experiment_name=raster_experiment \
#     py_func=train \
#     +training=training_raster_model \
#     scenario_builder=nuplan_mini \
#     scenario_filter.limit_total_scenarios=500 \
#     lightning.trainer.params.max_epochs=10 \
#     data_loader.params.batch_size=8 \
#     data_loader.params.num_workers=8
# ```

# %% [markdown]
# # Simulating a planner <a name="simulation"></a>

# %% [markdown]
# ## Open-loop simulation
# Open-loop simulation aims to evaluate the policy's capabilities to imitate the expert driver's behavior.<br />
# This is essentially done through log replay as the policy's predictions do not affect the state of the simulation.
#
# As the policy is not in full control of the vehicle, this type of simulation can only provide a high-level performance overview.
#
# ## Closed-loop simulation
# Conversely, in closed-loop simulation the policy's actions alter the state of the simulation which tries to closely approximate the real-world system.
#
# The simulation's feedback loop enables a more in-depth evaluation of the policy as compounding errors can cause future observations to significantly diverge from the ground truth.<br />
# This is important in measuring distribution shifts introduced due to lack of variance in training examples through pure imitation learning.
#
# Closed-loop simulation is further divided into two categories:
# * ego closed-loop simulation with agents replayed from log (open-loop, non reactive)
# * ego closed-loop simulation with agents controlled by a rule-based or learned policy (closed-loop, reactive)
#
# ## Measuring success
# Measuring the success of a planning task and comparing various planning policies is a complicated effort that involves defining metrics across different vertical dimensions and scenario categories.<br />
# These metrics include indicators such as vehicle dynamics, traffic rule violations, expert imitation, navigation success etc.<br />
# Overall, they aim to capture the policy's ability to control the autonomous vehicle safely yet efficiently without compromising the passenger's comfort.

# %% [markdown]
# ## Simulation parameters

# %% [markdown]
# ### Planners
#
# Change the planner model with `planner=X` where `X` is a config yaml defined in the table below.
#
# | Planner | Description | Config |
# | --- | --- | --- |
# | Simple Planner | Naive planner that only plans a straight path | `simple_planner` |
# | ML Planner | Learning-based planner trained using the nuPlan training framework (see previous section) | `ml_planner` |

# %% [markdown]
# ## Prepare the simulation config

# %%
# Location of path with all simulation configs
CONFIG_PATH = '../nuplan/planning/script/config/simulation'
CONFIG_NAME = 'default_simulation'

# Select the planner and simulation challenge
PLANNER = 'simple_planner'  # [simple_planner, ml_planner]
CHALLENGE = 'closed_loop_reactive_agents'  # [open_loop_boxes, closed_loop_nonreactive_agents, closed_loop_reactive_agents]
DATASET_PARAMS = [
    'scenario_builder=nuplan_mini',  # use nuplan mini database
    'scenario_filter=all_scenarios',  # initially select all scenarios in the database
    'scenario_filter.scenario_types=[near_multiple_vehicles, on_pickup_dropoff, starting_unprotected_cross_turn, high_magnitude_jerk]',  # select scenario types
    'scenario_filter.num_scenarios_per_type=10',  # use 10 scenarios per scenario type
]

# Name of the experiment
EXPERIMENT = 'simulation_simple_experiment'

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    f'experiment_name={EXPERIMENT}',
    f'group={SAVE_DIR}',
    f'planner={PLANNER}',
    f'+simulation={CHALLENGE}',
    *DATASET_PARAMS,
])

# %% [markdown]
# ## Launch simulation (within the notebook)

# %%
from nuplan.planning.script.run_simulation import main as main_simulation

# Run the simulation loop (real-time visualization not yet supported, see next section for visualization)
main_simulation(cfg)

# Simple simulation folder for visualization in nuBoard
simple_simulation_folder = cfg.output_dir
# Out:
# Global seed set to 0
# 2026-07-07 15:27:10,682 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:20}  Building MultiMainCallback...
# 2026-07-07 15:27:10,768 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:35}  Building MultiMainCallback: 4...DONE!
# 2026-07-07 15:27:10,958 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2026-07-07 15:27:10,959 WARNING {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:135}  Ray is running, we will shut it down before starting again!
# 2026-07-07 15:27:13,248 INFO {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:78}  Starting ray local!
# 2026-07-07 15:27:15,757	INFO worker.py:1518 -- Started a local Ray instance.
# 2026-07-07 15:27:16,325 INFO {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2026-07-07 15:27:16,326 INFO {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 12
# Number of GPUs per node: 1
# Number of threads across all nodes: 12
# 2026-07-07 15:27:16,326 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2026-07-07 15:27:16,326 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:32}  Building experiment folders...
# 2026-07-07 15:27:16,327 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:35}
#
# 	Folder where all results are stored: /tmp/tutorial_nuplan_framework/simulation_simple_experiment/closed_loop_reactive_agents/2026.07.07.15.27.10
#
# 2026-07-07 15:27:16,330 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:70}  Building experiment folders...DONE!
# 2026-07-07 15:27:16,330 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:52}  Building AbstractCallback...
# 2026-07-07 15:27:16,330 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:68}  Building AbstractCallback: 0...DONE!
# 2026-07-07 15:27:16,330 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:47}  Building simulations...
# 2026-07-07 15:27:16,330 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:53}  Extracting scenarios...
# 2026-07-07 15:27:16,331 INFO {/root/nuplan-devkit/nuplan/common/utils/distributed_scenario_filter.py:83}  Building Scenarios in mode DistributedMode.SINGLE_NODE
# 2026-07-07 15:27:16,331 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2026-07-07 15:27:16,343 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2026-07-07 15:27:16,343 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2026-07-07 15:27:16,345 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# Ray objects: 100%|████████████████████████████████████████████████████████████████████| 12/12 [00:01<00:00,  7.21it/s]
# 2026-07-07 15:27:18,037 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:74}  Building metric engines...
# 2026-07-07 15:27:18,449 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:76}  Building metric engines...DONE
# 2026-07-07 15:27:18,449 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:80}  Building simulations from 31 scenarios...
# 2026-07-07 15:27:18,729 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:133}  Building simulations...DONE!
# 2026-07-07 15:27:18,729 INFO {/root/nuplan-devkit/nuplan/planning/script/run_simulation.py:78}  Running simulation...
# 2026-07-07 15:27:18,729 INFO {/root/nuplan-devkit/nuplan/planning/script/utils.py:138}  Executing runners...
# 2026-07-07 15:27:18,730 INFO {/root/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:82}  Starting 31 simulations using RayDistributed!
# Converting detections to smart agents:   0%|          | 0/41 [00:00<?, ?it/s]                  | 0/31 [00:00<?, ?it/s](wrapped_fn pid=37119)
# Converting detections to smart agents:   0%|          | 0/4 [00:00<?, ?it/s]
# Converting detections to smart agents:   0%|          | 0/39 [00:00<?, ?it/s]
# Converting detections to smart agents:   0%|          | 0/52 [00:00<?, ?it/s]
# Converting detections to smart agents:   0%|          | 0/21 [00:00<?, ?it/s]
# Converting detections to smart agents:   0%|          | 0/39 [00:00<?, ?it/s]
# Converting detections to smart agents:   0%|          | 0/31 [00:00<?, ?it/s]
# Converting detections to smart agents:   0%|          | 0/25 [00:00<?, ?it/s]
# Converting detections to smart agents:   0%|          | 0/20 [00:00<?, ?it/s]
# Converting detections to smart agents:   0%|          | 0/62 [00:00<?, ?it/s]
# Converting detections to smart agents:   0%|          | 0/32 [00:00<?, ?it/s]
# Converting detections to smart agents:   0%|          | 0/39 [00:00<?, ?it/s]
#
# Converting detections to smart agents:   5%|▌         | 1/20 [00:00<00:11,  1.68it/s]
# Converting detections to smart agents:   2%|▏         | 1/41 [00:00<00:28,  1.39it/s]
#
#
# Converting detections to smart agents:   2%|▏         | 1/52 [00:00<00:48,  1.06it/s]
# Converting detections to smart agents:   2%|▏         | 1/62 [00:00<00:58,  1.04it/s]
#
# Converting detections to smart agents:   3%|▎         | 1/32 [00:00<00:30,  1.02it/s]
# Converting detections to smart agents:   3%|▎         | 1/39 [00:01<00:39,  1.04s/it]
# Converting detections to smart agents:   3%|▎         | 1/31 [00:00<00:29,  1.03it/s]
# Converting detections to smart agents:   3%|▎         | 1/39 [00:01<00:41,  1.08s/it]
# Converting detections to smart agents:  31%|███       | 19/62 [00:01<00:01, 24.17it/s]
#
# Converting detections to smart agents:  41%|████      | 16/39 [00:01<00:01, 18.92it/s]
# Converting detections to smart agents:   3%|▎         | 1/39 [00:01<00:39,  1.05s/it]
#
# Converting detections to smart agents:   4%|▍         | 1/25 [00:01<00:26,  1.11s/it]
#
# Converting detections to smart agents:  33%|███▎      | 17/52 [00:01<00:01, 19.44it/s]
# Converting detections to smart agents:  50%|█████     | 31/62 [00:01<00:00, 36.93it/s]
#
# Converting detections to smart agents:  51%|█████▏    | 20/39 [00:01<00:00, 23.62it/s]
#
#
#
#
# Converting detections to smart agents:   0%|          | 0/13 [00:00<?, ?it/s]          | 1/31 [00:05<02:35,  5.18s/it](wrapped_fn pid=37109)
# Converting detections to smart agents:   8%|▊         | 1/13 [00:00<00:04,  2.82it/s]
#
# Converting detections to smart agents:   0%|          | 0/37 [00:00<?, ?it/s]          | 2/31 [00:08<01:53,  3.90s/it](wrapped_fn pid=37119)
# Converting detections to smart agents:   3%|▎         | 1/37 [00:01<00:37,  1.04s/it]
#                                                                                        | 3/31 [00:09<01:14,  2.65s/it](wrapped_fn pid=37119)
# Converting detections to smart agents:   0%|          | 0/18 [00:00<?, ?it/s]
# Converting detections to smart agents:   0%|          | 0/30 [00:00<?, ?it/s]          | 4/31 [00:09<00:46,  1.71s/it](wrapped_fn pid=37118)
#
#                                                                                        | 5/31 [00:10<00:36,  1.42s/it](wrapped_fn pid=37109)
# Converting detections to smart agents:   6%|▌         | 1/18 [00:01<00:18,  1.08s/it]
#
# Converting detections to smart agents:   0%|          | 0/2 [00:00<?, ?it/s]           | 6/31 [00:16<01:18,  3.13s/it](wrapped_fn pid=37109)
#                                                                                        | 7/31 [00:17<00:56,  2.36s/it](wrapped_fn pid=37112)
#
# Converting detections to smart agents:   0%|          | 0/11 [00:00<?, ?it/s]          | 8/31 [00:19<00:47,  2.05s/it](wrapped_fn pid=37116)
#                                                                                        | 9/31 [00:19<00:32,  1.48s/it](wrapped_fn pid=37113)
# Converting detections to smart agents:   0%|          | 0/28 [00:00<?, ?it/s]         | 10/31 [00:19<00:24,  1.15s/it](wrapped_fn pid=37115)
#
# Converting detections to smart agents:  21%|██▏       | 6/28 [00:00<00:00, 47.37it/s]
#
# Converting detections to smart agents:   0%|          | 0/25 [00:00<?, ?it/s]         | 12/31 [00:20<00:13,  1.39it/s](wrapped_fn pid=37119)
# Converting detections to smart agents:   0%|          | 0/48 [00:00<?, ?it/s]
# Converting detections to smart agents:  71%|███████   | 34/48 [00:00<00:00, 334.36it/s]
#
#
# Converting detections to smart agents:   0%|          | 0/26 [00:00<?, ?it/s]         | 13/31 [00:20<00:11,  1.56it/s](wrapped_fn pid=37110)
# Converting detections to smart agents:   4%|▍         | 1/26 [00:00<00:17,  1.46it/s]
#
#                                                                                       | 14/31 [00:23<00:19,  1.14s/it](wrapped_fn pid=37111)
# Converting detections to smart agents:   0%|          | 0/20 [00:00<?, ?it/s]         | 15/31 [00:23<00:15,  1.01it/s](wrapped_fn pid=37114)
#
# Converting detections to smart agents:   0%|          | 0/26 [00:00<?, ?it/s]         | 16/31 [00:25<00:15,  1.06s/it](wrapped_fn pid=37116)
#                                                                                       | 17/31 [00:25<00:11,  1.23it/s](wrapped_fn pid=37116)
#
# Converting detections to smart agents:   0%|          | 0/7 [00:00<?, ?it/s]
#
#                                                                                       | 19/31 [00:26<00:09,  1.33it/s](wrapped_fn pid=37113)
# Ray objects: 100%|████████████████████████████████████████████████████████████████████| 31/31 [00:40<00:00,  1.29s/it]
# 2026-07-07 15:27:58,864 INFO {/root/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:127}  Number of successful simulations: 31
# 2026-07-07 15:27:58,864 INFO {/root/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:128}  Number of failed simulations: 0
# 2026-07-07 15:27:58,864 INFO {/root/nuplan-devkit/nuplan/planning/script/utils.py:147}  Finished executing runners!
# 2026-07-07 15:27:58,875 INFO {/root/nuplan-devkit/nuplan/planning/script/utils.py:74}  Saved runner reports to /tmp/tutorial_nuplan_framework/simulation_simple_experiment/closed_loop_reactive_agents/2026.07.07.15.27.10/runner_report.parquet
# 2026-07-07 15:27:58,875 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/time_callback.py:27}  Simulation duration: 00:00:48 [HH:MM:SS]
# 2026-07-07 15:27:59,501 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_file_callback.py:79}  Metric files integration: 00:00:00 [HH:MM:SS]
# 2026-07-07 15:27:59,566 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:58}  Running metric aggregator: closed_loop_reactive_agents_weighted_average
# 2026-07-07 15:27:59,605 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:69}  Metric aggregator: 00:00:00 [HH:MM:SS]
# Rendering histograms:   6%|███▌                                                        | 1/17 [00:00<00:03,  4.59it/s]
# 2026-07-07 15:27:59,761 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-07 15:27:59,763 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Rendering histograms:  65%|██████████████████████████████████████▏                    | 11/17 [00:01<00:00,  7.23it/s]
# 2026-07-07 15:28:01,577 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-07 15:28:01,579 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-07 15:28:01,586 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-07 15:28:01,588 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-07 15:28:01,592 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-07 15:28:01,594 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-07 15:28:01,599 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-07 15:28:01,601 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Rendering histograms: 100%|███████████████████████████████████████████████████████████| 17/17 [00:03<00:00,  5.29it/s]
# 2026-07-07 15:28:04,846 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_summary_callback.py:344}  Metric summary: 00:00:05 [HH:MM:SS]
# 2026-07-07 15:28:04,846 INFO {/root/nuplan-devkit/nuplan/planning/script/run_simulation.py:80}  Finished running simulation!

# %% [markdown]
# ## Launch simulation (command line - alternative)

# %% [markdown]
# A simulation experiment can be launched alternatively with:
# ```
# $ python nuplan/planning/script/run_simulation.py \
#     +simulation=open_loop_boxes \
#     planner=simple_planner \
#     scenario_builder=nuplan_mini \
#     scenario_filter=all_scenarios \
#     scenario_filter.scenario_types="[near_multiple_vehicles, on_pickup_dropoff, starting_unprotected_cross_turn, high_magnitude_jerk]" \
#     scenario_filter.num_scenarios_per_type=10 \
# ```

# %% [markdown]
# ## Simulate a trained ML planner for comparison
#
# Using the same simulation settings as before, we can simulate a pretrained ML planner and compare the two.
#
# In this example you can take the model you trained earlier.

# %%
# Location of path with all simulation configs
CONFIG_PATH = '../nuplan/planning/script/config/simulation'
CONFIG_NAME = 'default_simulation'

# Get the checkpoint of the trained model
last_experiment = sorted(os.listdir(LOG_DIR))[-1]
train_experiment_dir = sorted(LOG_DIR.iterdir())[-1]
checkpoint = sorted((train_experiment_dir / 'checkpoints').iterdir())[-1]

MODEL_PATH = str(checkpoint).replace("=", "\=")

# Name of the experiment
EXPERIMENT = 'simulation_raster_experiment'

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    f'experiment_name={EXPERIMENT}',
    f'group={SAVE_DIR}',
    'planner=ml_planner',
    'model=raster_model',
    'planner.ml_planner.model_config=${model}',  # hydra notation to select model config
    f'planner.ml_planner.checkpoint_path={MODEL_PATH}',  # this path can be replaced by the checkpoint of the model trained in the previous section
    f'+simulation={CHALLENGE}',
    *DATASET_PARAMS,
])

# Run the simulation loop
main_simulation(cfg)

# ML_planner simulation folder for visualization in nuBoard (next section)
ml_planner_simulation_folder = cfg.output_dir
# Out:
# Global seed set to 0
# 2026-07-07 15:28:13,530 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:20}  Building MultiMainCallback...
# 2026-07-07 15:28:13,551 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:35}  Building MultiMainCallback: 4...DONE!
# 2026-07-07 15:28:13,749 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2026-07-07 15:28:13,749 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2026-07-07 15:28:13,751 WARNING {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:135}  Ray is running, we will shut it down before starting again!
# 2026-07-07 15:28:13,751 WARNING {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:135}  Ray is running, we will shut it down before starting again!
# 2026-07-07 15:28:15,787 INFO {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:78}  Starting ray local!
# 2026-07-07 15:28:15,787 INFO {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:78}  Starting ray local!
# 2026-07-07 15:28:18,319	INFO worker.py:1518 -- Started a local Ray instance.
# 2026-07-07 15:28:18,938 INFO {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2026-07-07 15:28:18,938 INFO {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2026-07-07 15:28:18,938 INFO {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 12
# Number of GPUs per node: 1
# Number of threads across all nodes: 12
# 2026-07-07 15:28:18,938 INFO {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 12
# Number of GPUs per node: 1
# Number of threads across all nodes: 12
# 2026-07-07 15:28:18,939 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2026-07-07 15:28:18,939 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2026-07-07 15:28:18,939 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:32}  Building experiment folders...
# 2026-07-07 15:28:18,939 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:32}  Building experiment folders...
# 2026-07-07 15:28:18,939 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:35}
#
# 	Folder where all results are stored: /tmp/tutorial_nuplan_framework/simulation_raster_experiment/closed_loop_reactive_agents/2026.07.07.15.28.13
#
# 2026-07-07 15:28:18,939 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:35}
#
# 	Folder where all results are stored: /tmp/tutorial_nuplan_framework/simulation_raster_experiment/closed_loop_reactive_agents/2026.07.07.15.28.13
#
# 2026-07-07 15:28:18,941 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:70}  Building experiment folders...DONE!
# 2026-07-07 15:28:18,941 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:70}  Building experiment folders...DONE!
# 2026-07-07 15:28:18,941 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:52}  Building AbstractCallback...
# 2026-07-07 15:28:18,941 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:52}  Building AbstractCallback...
# 2026-07-07 15:28:18,942 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:68}  Building AbstractCallback: 0...DONE!
# 2026-07-07 15:28:18,942 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:68}  Building AbstractCallback: 0...DONE!
# 2026-07-07 15:28:18,942 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:47}  Building simulations...
# 2026-07-07 15:28:18,942 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:47}  Building simulations...
# 2026-07-07 15:28:18,942 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:53}  Extracting scenarios...
# 2026-07-07 15:28:18,942 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:53}  Extracting scenarios...
# 2026-07-07 15:28:18,942 INFO {/root/nuplan-devkit/nuplan/common/utils/distributed_scenario_filter.py:83}  Building Scenarios in mode DistributedMode.SINGLE_NODE
# 2026-07-07 15:28:18,942 INFO {/root/nuplan-devkit/nuplan/common/utils/distributed_scenario_filter.py:83}  Building Scenarios in mode DistributedMode.SINGLE_NODE
# 2026-07-07 15:28:18,943 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2026-07-07 15:28:18,943 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2026-07-07 15:28:18,955 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2026-07-07 15:28:18,955 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2026-07-07 15:28:18,955 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2026-07-07 15:28:18,955 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2026-07-07 15:28:18,956 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# 2026-07-07 15:28:18,956 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# Ray objects: 100%|████████████████████████████████████████████████████████████████████| 12/12 [00:01<00:00,  6.79it/s]
# 2026-07-07 15:28:20,752 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:74}  Building metric engines...
# 2026-07-07 15:28:20,752 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:74}  Building metric engines...
# 2026-07-07 15:28:20,814 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:76}  Building metric engines...DONE
# 2026-07-07 15:28:20,814 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:76}  Building metric engines...DONE
# 2026-07-07 15:28:20,814 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:80}  Building simulations from 31 scenarios...
# 2026-07-07 15:28:20,814 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:80}  Building simulations from 31 scenarios...
# 2026-07-07 15:28:20,815 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:20,815 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:21,086 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:21,086 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:21,142 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:21,142 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:21,161 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:21,161 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:21,428 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:21,428 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:21,703 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:21,703 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:21,758 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:21,758 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:21,777 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:21,777 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:22,311 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:22,311 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:22,585 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:22,585 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:22,644 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:22,644 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:22,661 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:22,661 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:22,926 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:22,926 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:23,199 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:23,199 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:23,254 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:23,254 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:23,270 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:23,270 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:23,819 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:23,819 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:24,089 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:24,089 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:24,142 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:24,142 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:24,158 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:24,158 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:24,691 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:24,691 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:24,965 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:24,965 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:25,019 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:25,019 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:25,035 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:25,035 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:25,305 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:25,305 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:25,579 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:25,579 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:25,633 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:25,633 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:25,649 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:25,649 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:26,208 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:26,208 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:26,453 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:26,453 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:26,475 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:26,475 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:26,488 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:26,488 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:26,977 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:26,977 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:27,224 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:27,224 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:27,255 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:27,255 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:27,268 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:27,268 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:27,495 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:27,495 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:27,743 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:27,743 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:27,766 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:27,766 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:27,778 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:27,778 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:28,290 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:28,290 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:28,538 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:28,538 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:28,568 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:28,568 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:28,581 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:28,581 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:28,806 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:28,806 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:29,055 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:29,055 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:29,077 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:29,077 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:29,090 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:29,090 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:29,593 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:29,593 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:29,842 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:29,842 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:29,874 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:29,874 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:29,886 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:29,886 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:30,398 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:30,398 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:30,646 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:30,646 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:30,671 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:30,671 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:30,683 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:30,683 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:30,890 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:30,890 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:31,137 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:31,137 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:31,168 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:31,168 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:31,181 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:31,181 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:31,717 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:31,717 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:31,965 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:31,965 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:31,988 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:31,988 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:32,001 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:32,001 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:32,208 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:32,208 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:32,453 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:32,453 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:32,484 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:32,484 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:32,497 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:32,497 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:33,050 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:33,050 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:33,294 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:33,294 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:33,317 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:33,317 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:33,330 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:33,330 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:33,542 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:33,542 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:33,791 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:33,791 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:33,821 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:33,821 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:33,834 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:33,834 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:34,371 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:34,371 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:34,620 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:34,620 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:34,643 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:34,643 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:34,656 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:34,656 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:35,158 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:35,158 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:35,410 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:35,410 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:35,441 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:35,441 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:35,454 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:35,454 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:35,684 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:35,684 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:35,934 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:35,934 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:35,957 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:35,957 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:35,969 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:35,969 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:36,503 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:36,503 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:36,752 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:36,752 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:36,783 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:36,783 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:36,796 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:36,796 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:37,026 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:37,026 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:37,276 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:37,276 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:37,298 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:37,298 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:37,311 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:37,311 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:37,843 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:37,843 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:38,090 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:38,090 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:38,121 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:38,121 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:38,134 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:38,134 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:38,665 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:38,665 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:38,915 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:38,915 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:38,938 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:38,938 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:38,950 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:38,950 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:39,164 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:39,164 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:39,416 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:39,416 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:39,448 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:39,448 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:39,461 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:39,461 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-07 15:28:40,019 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:40,019 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-07 15:28:40,270 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:40,270 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-07 15:28:40,292 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-07 15:28:40,292 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# ...
# Converting detections to smart agents:   2%|▏         | 1/62 [00:01<01:08,  1.13s/it]
# (wrapped_fn pid=37868) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=37868)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Converting detections to smart agents:  67%|██████▋   | 35/52 [00:01<00:00, 38.84it/s]
# Converting detections to smart agents:  26%|██▌       | 16/62 [00:01<00:02, 17.59it/s]
#
# Converting detections to smart agents:  74%|███████▍  | 46/62 [00:01<00:00, 56.56it/s]
# (wrapped_fn pid=37869) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=37869)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
#
# (wrapped_fn pid=37871) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=37871)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Converting detections to smart agents:   0%|          | 0/13 [00:00<?, ?it/s]          | 1/31 [00:42<21:10, 42.35s/it](wrapped_fn pid=37872)
#
# Converting detections to smart agents:   0%|          | 0/37 [00:00<?, ?it/s]          | 2/31 [00:43<08:52, 18.38s/it](wrapped_fn pid=37865)
# Converting detections to smart agents:   3%|▎         | 1/37 [00:01<00:45,  1.25s/it]
#
# Converting detections to smart agents:   0%|          | 0/18 [00:00<?, ?it/s]          | 3/31 [00:45<05:03, 10.84s/it](wrapped_fn pid=37867)
# Converting detections to smart agents:   6%|▌         | 1/18 [00:01<00:18,  1.09s/it]  | 4/31 [00:46<03:07,  6.94s/it](wrapped_fn pid=37867)
# Converting detections to smart agents:   0%|          | 0/30 [00:00<?, ?it/s]
#
#
# Converting detections to smart agents:   0%|          | 0/15 [00:00<?, ?it/s]          | 5/31 [00:55<03:13,  7.45s/it](wrapped_fn pid=37870)
#
#
# Converting detections to smart agents:   0%|          | 0/21 [00:00<?, ?it/s]          | 7/31 [00:57<01:44,  4.37s/it](wrapped_fn pid=37866)
#
# Converting detections to smart agents:   0%|          | 0/11 [00:00<?, ?it/s]          | 9/31 [00:58<00:54,  2.48s/it](wrapped_fn pid=37876)
#
#
# Converting detections to smart agents:   0%|          | 0/28 [00:00<?, ?it/s]         | 10/31 [01:02<00:57,  2.73s/it](wrapped_fn pid=37868)
#
# Converting detections to smart agents:   0%|          | 0/25 [00:00<?, ?it/s]         | 11/31 [01:02<00:43,  2.15s/it](wrapped_fn pid=37869)
# Converting detections to smart agents:   4%|▍         | 1/25 [00:00<00:13,  1.79it/s]
#
# Converting detections to smart agents:   0%|          | 0/48 [00:00<?, ?it/s]         | 12/31 [01:05<00:46,  2.44s/it](wrapped_fn pid=37871)
# Converting detections to smart agents:  58%|█████▊    | 28/48 [00:00<00:00, 276.20it/s]
#
# Converting detections to smart agents:   0%|          | 0/26 [00:00<?, ?it/s]         | 13/31 [01:23<02:05,  6.96s/it](wrapped_fn pid=37872)
# Converting detections to smart agents:   4%|▍         | 1/26 [00:00<00:18,  1.38it/s]
# Converting detections to smart agents:   0%|          | 0/14 [00:00<?, ?it/s]         | 14/31 [01:34<02:18,  8.15s/it](wrapped_fn pid=37865)
#
# Converting detections to smart agents:   0%|          | 0/20 [00:00<?, ?it/s]         | 16/31 [01:38<01:13,  4.92s/it](wrapped_fn pid=37870)
# Converting detections to smart agents:   0%|          | 0/26 [00:00<?, ?it/s]
#
#
# Converting detections to smart agents:   0%|          | 0/13 [00:00<?, ?it/s]         | 17/31 [01:40<00:53,  3.80s/it](wrapped_fn pid=37875)
#
#                                                                                       | 18/31 [01:40<00:37,  2.91s/it](wrapped_fn pid=37876)
#                                                                                       | 19/31 [01:45<00:40,  3.39s/it](wrapped_fn pid=37874)
# Ray objects: 100%|████████████████████████████████████████████████████████████████████| 31/31 [02:33<00:00,  4.95s/it]
# 2026-07-07 15:31:19,834 INFO {/root/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:127}  Number of successful simulations: 31
# 2026-07-07 15:31:19,834 INFO {/root/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:127}  Number of successful simulations: 31
# 2026-07-07 15:31:19,835 INFO {/root/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:128}  Number of failed simulations: 0
# 2026-07-07 15:31:19,835 INFO {/root/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:128}  Number of failed simulations: 0
# 2026-07-07 15:31:19,835 INFO {/root/nuplan-devkit/nuplan/planning/script/utils.py:147}  Finished executing runners!
# 2026-07-07 15:31:19,835 INFO {/root/nuplan-devkit/nuplan/planning/script/utils.py:147}  Finished executing runners!
# 2026-07-07 15:31:19,847 INFO {/root/nuplan-devkit/nuplan/planning/script/utils.py:74}  Saved runner reports to /tmp/tutorial_nuplan_framework/simulation_raster_experiment/closed_loop_reactive_agents/2026.07.07.15.28.13/runner_report.parquet
# 2026-07-07 15:31:19,847 INFO {/root/nuplan-devkit/nuplan/planning/script/utils.py:74}  Saved runner reports to /tmp/tutorial_nuplan_framework/simulation_raster_experiment/closed_loop_reactive_agents/2026.07.07.15.28.13/runner_report.parquet
# 2026-07-07 15:31:19,847 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/time_callback.py:27}  Simulation duration: 00:03:06 [HH:MM:SS]
# 2026-07-07 15:31:19,847 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/time_callback.py:27}  Simulation duration: 00:03:06 [HH:MM:SS]
# 2026-07-07 15:31:20,273 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_file_callback.py:79}  Metric files integration: 00:00:00 [HH:MM:SS]
# 2026-07-07 15:31:20,273 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_file_callback.py:79}  Metric files integration: 00:00:00 [HH:MM:SS]
# 2026-07-07 15:31:20,335 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:58}  Running metric aggregator: closed_loop_reactive_agents_weighted_average
# 2026-07-07 15:31:20,335 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:58}  Running metric aggregator: closed_loop_reactive_agents_weighted_average
# 2026-07-07 15:31:20,374 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:69}  Metric aggregator: 00:00:00 [HH:MM:SS]
# 2026-07-07 15:31:20,374 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:69}  Metric aggregator: 00:00:00 [HH:MM:SS]
# Rendering histograms:   6%|███▌                                                        | 1/17 [00:00<00:03,  4.90it/s]
# 2026-07-07 15:31:20,536 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-07 15:31:20,536 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-07 15:31:20,539 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-07 15:31:20,539 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Rendering histograms:  65%|██████████████████████████████████████▏                    | 11/17 [00:01<00:00,  6.80it/s]
# 2026-07-07 15:31:22,326 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-07 15:31:22,326 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-07 15:31:22,330 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-07 15:31:22,330 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-07 15:31:22,336 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-07 15:31:22,336 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-07 15:31:22,339 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-07 15:31:22,339 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-07 15:31:22,345 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-07 15:31:22,345 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-07 15:31:22,348 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-07 15:31:22,348 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-07 15:31:22,354 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-07 15:31:22,354 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-07 15:31:22,358 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-07-07 15:31:22,358 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/matplotlib/category.py:234}  Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Rendering histograms: 100%|███████████████████████████████████████████████████████████| 17/17 [00:03<00:00,  5.00it/s]
# 2026-07-07 15:31:25,692 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_summary_callback.py:344}  Metric summary: 00:00:05 [HH:MM:SS]
# 2026-07-07 15:31:25,692 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_summary_callback.py:344}  Metric summary: 00:00:05 [HH:MM:SS]
# 2026-07-07 15:31:25,692 INFO {/root/nuplan-devkit/nuplan/planning/script/run_simulation.py:80}  Finished running simulation!
# 2026-07-07 15:31:25,692 INFO {/root/nuplan-devkit/nuplan/planning/script/run_simulation.py:80}  Finished running simulation!

# %% [markdown]
# # Visualizing metrics and scenarios <a name="dashboard"></a>

# %% [markdown]
# ## nuBoard summary
#
# Having trained and simulated planners across various scenarios and driving behaviors, it's time to evaluate them:
# * quantitatively, through common and scenario dependent metrics
# * qualitatively, through visualization of scenario progression
#
# ### nuBoard tabs
# To achieve that, nuBoard has 3 core evaluation tabs:
# 1. Overview - Scalar metrics summary of common and scenario metrics across the following categories:
#     * Ego dynamics
#     * Traffic violations
#     * Expert imitation
#     * Planning & navigation
#     * Scenario performance
# 2. Histograms - Histograms over metric statistics for more a granular peek inside each metric focusing on:
#     * Metric statistics (e.g. min, max, p90)
# 3. Scenarios - Low-level scenario visualizations:
#     * Time-series progression of a specific metric across a scenario
#     * Top-down visualization of the scenario across time for comparing predicted vs. expert trajectories
#
# In addition, there is a main configuration tab for selecting different simulation files for comparing planners/experiments.
#
# <br />
#
# **NOTE**: nuBoard is under heavy developement, overall functionality and aesthetics do not represent the final product!

# %% [markdown]
# ## Prepare the nuBoard config

# %%
# Location of path with all nuBoard configs
CONFIG_PATH = '../nuplan/planning/script/config/nuboard'
CONFIG_NAME = 'default_nuboard'

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    'scenario_builder=nuplan_mini',  # set the database (same as simulation) used to fetch data for visualization
    f'simulation_path={[simple_simulation_folder, ml_planner_simulation_folder]}',  # nuboard file path(s), if left empty the user can open the file inside nuBoard
])

# %% [markdown]
# ## Launch nuBoard (open in new tab - recommended)

# %%
from nuplan.planning.script.run_nuboard import main as main_nuboard

# Run nuBoard
main_nuboard(cfg)

# %% [markdown]
# ## Launch nuBoard (embedded within the notebook - alternative)

# %%
from bokeh.io import show, output_notebook
from nuplan.planning.script.run_nuboard import initialize_nuboard

# Make sure that the notebook working directory is "/notebooks" and that Jupyter was launched at the root of the repo
cfg.resource_prefix = '/notebooks/nuplan/planning/metrics/board/'  # pass CSS resources to the notebook

# Run the nuBoard
output_notebook()
nuboard = initialize_nuboard(cfg)
show(nuboard.main_page)

# %% [markdown]
# ## Launch nuBoard (command line - alternative)

# %% [markdown]
# nuBoard can be launched alternatively with:
# ```
# $ python nuplan/planning/script/run_nuboard.py
# ```
#
# Simulation files (.nuboard) can be selected under the configuration tab.
