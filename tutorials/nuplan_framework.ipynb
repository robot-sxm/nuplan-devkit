# %% [markdown]
# ![](https://www.nuplan.org/static/media/nuPlan_final.3fde7586.png)

# %% [markdown]
# ### Contents
#
# 1. [Introduction to nuPlan](#introduction)
# 2. [Training an ML planner](#training)
# 3. [Simulating a planner](#simulation)
# 4. [Visualizing metrics and scenarios](#dashboard)

# %%
from tutorials.utils.tutorial_utils import setup_notebook

setup_notebook()

import os
NUPLAN_DATA_ROOT = os.getenv('NUPLAN_DATA_ROOT', '~/nuplan')
NUPLAN_MAPS_ROOT = os.getenv('NUPLAN_MAPS_ROOT', '~/nuplan/dataset/maps')
NUPLAN_DB_FILES = os.getenv('NUPLAN_DB_FILES', '~/nuplan/dataset/nuplan-v1.1/splits/mini')
NUPLAN_MAP_VERSION = os.getenv('NUPLAN_MAP_VERSION', 'nuplan-maps-v1.0')

# %% [markdown]
# # Introduction to nuPlan <a name="introduction"></a>

# %% [markdown]
# Welcome to nuPlan! This notebook will explore the nuPlan simulation framework, training platform as well as the nuBoard metrics/scenarios visualization dashboard.

# %% [markdown]
# ## What is nuPlan
#
# nuPlan is the world’s first closed-loop ML-based planning benchmark for autonomous driving.
#
# It provides a high quality dataset with 1500h of human driving data from 4 cities across the US and Asia with widely varying traffic patterns (Boston, Pittsburgh, Las Vegas and Singapore). In addition, it provides a closed-loop simulation framework with reactive agents, a training platform as well as a large set of both general and scenario-specific planning metrics.
#
# ![](https://www.nuscenes.org/static/media/framework_steps.2d4642df.png)

# %% [markdown]
# ## Training & simulation framework
#
# The nuPlan training and simulation framework aims to:
# * create a simulation pipeline to evaluate a planner on large dataset with various scenarios
# * score planner performance with common and scenario-dependent metrics
# * compare planners based on measured metrics and provide intuitive visualizations
# * train planners with the provided framework to allow quick implementation and iteration
# * support closed-loop simulation and training
#
# <br />
#
# ![](https://www.nuplan.org/static/media/planning_framework.ca3c2969.png)

# %% [markdown]
# ## Scenarios in nuPlan
#
# nuPlan aims to capture challenging yet representative scenarios from real-world encounters. This enables the benchmarking of planning systems both in expert imitation (open-loop) and reactive planning (closed-loop) settings.
#
# These scenarios includes:
# * highly interactive scenes with traffic participants (e.g. tailgating, high-velocity overtakes, double parked cars, jaywalking)
# * various ego behaviors (e.g. vehicle following, yielding, lane merging) and dynamics (e.g. mixed speed profiles, abrupt braking, speed bumps, high jerk maneuvers)
# * scene layouts of varied complexity (e.g. pudos, traffic/stop controlled intersections, unprotected turns) and temporary zones (e.g. construction areas)
#
# The dataset is automatically tagged with scenario labels based on certain primitive attributes.
# These scenario tags can then be used to extract representative metrics for the planner's evaluation.
#
# Example mined scenarios in nuPlan:
#
# | | | |
# | :-: | :-: | :-: |
# | Unprotected cross turn | Dense vehicle interactions | Jaywalker in front |
# | ![](https://www.nuscenes.org/static/media/unprotected-cross.51feef7e.webp) | ![](https://www.nuscenes.org/static/media/dense-interactions.16de47ec.webp) | ![](https://www.nuscenes.org/static/media/jaywalker.03083823.webp) |
# | Lane change | Ego at pickup/dropoff area | Ego following vehicle |
# | ![](https://www.nuscenes.org/static/media/lane-change.54bfca1c.webp) | ![](https://www.nuscenes.org/static/media/pickup-dropoff.4dd1c418.webp) | ![](https://www.nuscenes.org/static/media/following-vehicle.4cacd559.webp) |

# %% [markdown]
# ## Database
#
# Download a database for training/simulation from [here](https://nuplan.org/nuplan#download).
#
# | Database | Size | Duration | Num Logs | Cities | Num Scenarios | Sensor Data | Description |
# | :-- | :-- | :-- | :-- | :-- | :-- | :-- | :-- |
# | nuplan_v1.1_mini (recommended) | 13GB | 7h | 64 | Las Vegas, Boston, Pittsburgh, Singapore | 67 | N/A | The mini split used for prototyping and testing |
# | nuplan_v1.1 | 1.8TB | 1282h | 15910 | Las Vegas, Boston, Pittsburgh, Singapore | 73 | N/A | The full dataset for training and evaluation|

# %% [markdown]
# ## Setup
#
# To be able to access all resources within this notebook, make sure Jupyter is launched at the root of this repo. The path of the notebook should be `/notebook/<repo_root>`.

# %%
# (Optional) Increase notebook width for all embedded cells to display properly
from IPython.core.display import display, HTML
display(HTML("<style>.output_result { max-width:100% !important; }</style>"))
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# /tmp/ipykernel_3197/4180358289.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.output_result { max-width:100% !important; }</style>
# <style>.container { width:100% !important; }</style>

# %%
# Useful imports
import os
from pathlib import Path
import tempfile

import hydra

# %% [markdown]
# # Training an ML planner <a name="training"></a>

# %% [markdown]
# ## Imitation learning
# In the following section we will train an ML planning policy with the aim estimate the ego's future trajectory and control the vehicle.
#
# The policy is learned through imitation learning, a supervised learning approach in which - in the context of autonomous driving - the behavior of an expert human driver is used as a target signal to supervise the model.
#
# ## Model features & targets
# A planning policy consumes a set of episodic observations and encodes them through a deep neural network to regress a future trajectory.
#
# The observations can be historic or present ego and agent poses as well as static/dynamic map information across different map layers.<br />
# These signals can be encoded through various representations, such as raster or vector format for the map signal, each with their pros and cons for each model flavor.
#
# Using these input features the model predicts a discretized future trajectory across a fixed time horizon.<br />
# The trajectory consists of a set of discrete future states (position, heading and velocity) sampled at fixed intervals which express the likelihood of the vehicle being at that state in the future.<br />
# For example, a predicted trajectory may consist of 10 future poses sampled at intervals of 0.5s across a 5s horizon.
#
# ## Learning objectives
# The policy is trained to maximize a set of aggregated objectives such as imitation, collision avoidance, traffic rule violation etc.<br />
# Imitation is the core training objective which indicates how close the predicted trajectory is to the expert ground truth and penalizes model predictions that deviate in space and time from the demonstration.

# %% [markdown]
# ## Training parameters

# %% [markdown]
# The following parameter categories define the training protocol which includes the model, metrics, objectives etc.
#
# A working example composition of these parameters can be found in the next section.
#
# ---
#
# ### ML models
#
# Change the training model with `model=X` where `X` is a config yaml defined in the table below.
#
# | Model | Description | Config |
# | --- | --- | --- |
# | Raster model (CNN) | Raster-based model that uses a CNN backbone to encode ego, agent and map information as raster layers<br />Any (pretrained) backbone from the TIMM library can be used (e.g. ResNet50, EfficientNetB3) | `raster_model` |
# | Vector model (LaneGCN) | Vector-based model that uses a series of MLPs to encode ego and agent signals, a lane graph to encode vector-map elements and a fusion network to capture lane & agent intra/inter-interactions through attention layers<br />Implementation of LaneGCN paper ("Learning Lane Graph Representations for Motion Forecasting") | `vector_model` |
# | Simple vector model | Toy vector-based model that consumes ego, agent and lane signals through a series of MLPs | `simple_vector_model` |
#
# <br />
#
# ### Training objectives
#
# Change the training objectives with `objective=[X, ...]` where `X` is a config yaml defined in the table below.
#
# | Objective | Description | Config |
# | --- | --- | --- |
# | Imitation objective | Penalizes the predicted trajectory that deviates from the expert demonstration | `imitation_objective` |
#
# <br />
#
# ### Training metrics
#
# Change the training objectives with `training_metric=[X, ...]` where `X` is a config yaml defined in the table below.
#
# | Metric | Description | Config |
# | --- | --- | --- |
# | Average displacement error | RMSE translation error across full predicted trajectory | `avg_displacement_error` |
# | Average heading error | RMSE heading error across full predicted trajectory | `avg_heading_error` |
# | Final displacement error | L2 error of predicted trajectory's final pose translation | `final_displacement_error` |
# | Final heading error | L2 error of predicted trajectory's final pose heading | `final_heading_error` |

# %% [markdown]
# ## Prepare the training config

# %%
# Location of path with all training configs
CONFIG_PATH = '../nuplan/planning/script/config/training'
CONFIG_NAME = 'default_training'

# Create a temporary directory to store the cache and experiment artifacts
SAVE_DIR = Path(tempfile.gettempdir()) / 'tutorial_nuplan_framework'  # optionally replace with persistent dir
EXPERIMENT = 'training_raster_experiment'
JOB_NAME = 'train_default_raster'
LOG_DIR = SAVE_DIR / EXPERIMENT / JOB_NAME

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    f'group={str(SAVE_DIR)}',
    f'cache.cache_path={str(SAVE_DIR)}/cache',
    f'experiment_name={EXPERIMENT}',
    f'job_name={JOB_NAME}',
    'py_func=train',
    '+training=training_raster_model',  # raster model that consumes ego, agents and map raster layers and regresses the ego's trajectory
    'scenario_builder=nuplan_mini',  # use nuplan mini database
    'scenario_filter.limit_total_scenarios=500',  # Choose 500 scenarios to train with
    'lightning.trainer.params.accelerator=ddp_spawn',  # ddp is not allowed in interactive environment, using ddp_spawn instead - this can bottleneck the data pipeline, it is recommended to run training outside the notebook
    'lightning.trainer.params.max_epochs=10',
    'data_loader.params.batch_size=8',
    'data_loader.params.num_workers=8',
])

# %% [markdown]
# ## Launch tensorboard for visualizing training artifacts

# %%
# %load_ext tensorboard
# %tensorboard --logdir {str(LOG_DIR)}
# Out:
#       <iframe id="tensorboard-frame-784e0a78933050fd" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-784e0a78933050fd");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## Launch training (within the notebook)

# %%
# import os

# # 先清掉所有可能影响 httpx / huggingface_hub 的代理变量
# for key in list(os.environ.keys()):
#     if "proxy" in key.lower():
#         print("delete", key, os.environ[key])
#         del os.environ[key]

# # 如果你要走本地 SOCKS5 代理，再重新设置为 httpx 支持的 scheme
# proxy = "socks5://127.0.0.1:7897"

# os.environ["HTTP_PROXY"] = proxy
# os.environ["HTTPS_PROXY"] = proxy
# os.environ["ALL_PROXY"] = proxy
# os.environ["http_proxy"] = proxy
# os.environ["https_proxy"] = proxy
# os.environ["all_proxy"] = proxy

# # 检查：这里不应该再出现 socks://
# for key, value in os.environ.items():
#     if "proxy" in key.lower():
#         print(key, value)


from nuplan.planning.script.run_training import main as main_train

# Run the training loop, optionally inspect training artifacts through tensorboard (above cell)
main_train(cfg)
# Out:
# Global seed set to 0
# 2026-07-03 09:42:28,588 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:20}  Building experiment folders...
# 2026-07-03 09:42:28,589 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:22}  Experimental folder: /tmp/tutorial_nuplan_framework/training_raster_experiment/train_default_raster/2026.07.03.09.42.28
# 2026-07-03 09:42:28,589 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2026-07-03 09:42:28,590 INFO {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:78}  Starting ray local!
# 2026-07-03 09:42:31,440	INFO worker.py:1518 -- Started a local Ray instance.
# 2026-07-03 09:42:32,038 INFO {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2026-07-03 09:42:32,039 INFO {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 12
# Number of GPUs per node: 1
# Number of threads across all nodes: 12
# 2026-07-03 09:42:32,039 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2026-07-03 09:42:32,040 INFO {/root/nuplan-devkit/nuplan/planning/training/experiments/training.py:41}  Building training engine...
# 2026-07-03 09:42:32,040 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:42:32,695 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:42:32,879 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:42:32,896 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:42:32,897 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/splitter_builder.py:18}  Building Splitter...
# 2026-07-03 09:42:33,771 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/splitter_builder.py:21}  Building Splitter...DONE!
# 2026-07-03 09:42:33,772 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2026-07-03 09:42:33,784 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2026-07-03 09:42:33,785 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2026-07-03 09:42:33,787 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# Ray objects: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:03<00:00,  3.68it/s]
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# Using native 16bit precision.
# Global seed set to 0
# initializing ddp: GLOBAL_RANK: 0, MEMBER: 1/1
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All DDP processes registered. Starting ddp with 1 processes
# ----------------------------------------------------------------------------------------------------
# 2026-07-03 09:42:37,190 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_builder.py:171}  Extracted 500 scenarios for training
# 2026-07-03 09:42:37,191 INFO {/root/nuplan-devkit/nuplan/planning/training/experiments/training.py:52}  Updating configs based on ddp_spawn strategy is currently not supported. Optimizer and LR Scheduler configs will not be updated.
# 2026-07-03 09:42:37,194 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/training_callback_builder.py:19}  Building callbacks...
# 2026-07-03 09:42:37,204 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/training_callback_builder.py:37}  Building callbacks...DONE!
# 2026-07-03 09:42:37,207 INFO {/root/nuplan-devkit/nuplan/planning/script/run_training.py:62}  Starting training...
# 2026-07-03 09:42:37,302 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:194}  Added key: store_based_barrier_key:1 to store for rank: 0
# 2026-07-03 09:42:37,302 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py:224}  Rank 0: Completed store-based barrier for 1 nodes.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type        | Params
# --------------------------------------
# 0 | model | RasterModel | 23.6 M
# --------------------------------------
# 23.6 M    Trainable params
# 0         Non-trainable params
# 23.6 M    Total params
# 94.438    Total estimated model params size (MB)
# 2026-07-03 09:42:42,829 INFO {/root/nuplan-devkit/nuplan/planning/training/data_loader/datamodule.py:47}  Number of samples in train set: 323
# 2026-07-03 09:42:42,830 INFO {/root/nuplan-devkit/nuplan/planning/training/data_loader/datamodule.py:47}  Number of samples in validation set: 82
# 2026-07-03 09:42:42,833 INFO {/root/nuplan-devkit/nuplan/planning/training/modeling/lightning_module_wrapper.py:196}  Using optimizer: torch.optim.Adam
# 2026-07-03 09:42:42,833 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/lr_scheduler_builder.py:52}  Not using any lr_schedulers.
# /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/pytorch_lightning/trainer/data_loading.py:73: UserWarning: num_workers>0, persistent_workers=False, and accelerator=ddp_spawn may result in data loading bottlenecks. Consider setting persistent_workers=True (this is a limitation of Python .spawn() and PyTorch)
#   rank_zero_warn(
# /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/pytorch_lightning/callbacks/lr_monitor.py:97: RuntimeWarning: You are using `LearningRateMonitor` callback with models that have no learning rate schedulers. Please see documentation for `configure_optimizers` method.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# 2026-07-03 09:42:49,139 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/torch/nn/parallel/distributed.py:788}  Reducer buckets have been rebuilt in this iteration.
# /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/pytorch_lightning/trainer/callback_hook.py:100: LightningDeprecationWarning: The signature of `Callback.on_train_epoch_end` has changed in v1.3. `outputs` parameter has been removed. Support for the old signature will be removed in v1.5
#   warning_cache.deprecation(
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Validating: 0it [00:00, ?it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)

# %% [markdown]
# ## Launch training (command line - alternative)

# %% [markdown]
# A training experiment with the above same parameters can be launched alternatively with:
# ```
# $ python nuplan/planning/script/run_training.py \
#     experiment_name=raster_experiment \
#     py_func=train \
#     +training=training_raster_model \
#     scenario_builder=nuplan_mini \
#     scenario_filter.limit_total_scenarios=500 \
#     lightning.trainer.params.max_epochs=10 \
#     data_loader.params.batch_size=8 \
#     data_loader.params.num_workers=8
# ```

# %% [markdown]
# # Simulating a planner <a name="simulation"></a>

# %% [markdown]
# ## Open-loop simulation
# Open-loop simulation aims to evaluate the policy's capabilities to imitate the expert driver's behavior.<br />
# This is essentially done through log replay as the policy's predictions do not affect the state of the simulation.
#
# As the policy is not in full control of the vehicle, this type of simulation can only provide a high-level performance overview.
#
# ## Closed-loop simulation
# Conversely, in closed-loop simulation the policy's actions alter the state of the simulation which tries to closely approximate the real-world system.
#
# The simulation's feedback loop enables a more in-depth evaluation of the policy as compounding errors can cause future observations to significantly diverge from the ground truth.<br />
# This is important in measuring distribution shifts introduced due to lack of variance in training examples through pure imitation learning.
#
# Closed-loop simulation is further divided into two categories:
# * ego closed-loop simulation with agents replayed from log (open-loop, non reactive)
# * ego closed-loop simulation with agents controlled by a rule-based or learned policy (closed-loop, reactive)
#
# ## Measuring success
# Measuring the success of a planning task and comparing various planning policies is a complicated effort that involves defining metrics across different vertical dimensions and scenario categories.<br />
# These metrics include indicators such as vehicle dynamics, traffic rule violations, expert imitation, navigation success etc.<br />
# Overall, they aim to capture the policy's ability to control the autonomous vehicle safely yet efficiently without compromising the passenger's comfort.

# %% [markdown]
# ## Simulation parameters

# %% [markdown]
# ### Planners
#
# Change the planner model with `planner=X` where `X` is a config yaml defined in the table below.
#
# | Planner | Description | Config |
# | --- | --- | --- |
# | Simple Planner | Naive planner that only plans a straight path | `simple_planner` |
# | ML Planner | Learning-based planner trained using the nuPlan training framework (see previous section) | `ml_planner` |

# %% [markdown]
# ## Prepare the simulation config

# %%
# Location of path with all simulation configs
CONFIG_PATH = '../nuplan/planning/script/config/simulation'
CONFIG_NAME = 'default_simulation'

# Select the planner and simulation challenge
PLANNER = 'simple_planner'  # [simple_planner, ml_planner]
CHALLENGE = 'open_loop_boxes'  # [open_loop_boxes, closed_loop_nonreactive_agents, closed_loop_reactive_agents]
DATASET_PARAMS = [
    'scenario_builder=nuplan_mini',  # use nuplan mini database
    'scenario_filter=all_scenarios',  # initially select all scenarios in the database
    'scenario_filter.scenario_types=[near_multiple_vehicles, on_pickup_dropoff, starting_unprotected_cross_turn, high_magnitude_jerk]',  # select scenario types
    'scenario_filter.num_scenarios_per_type=10',  # use 10 scenarios per scenario type
]

# Name of the experiment
EXPERIMENT = 'simulation_simple_experiment'

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    f'experiment_name={EXPERIMENT}',
    f'group={SAVE_DIR}',
    f'planner={PLANNER}',
    f'+simulation={CHALLENGE}',
    *DATASET_PARAMS,
])

# %% [markdown]
# ## Launch simulation (within the notebook)

# %%
from nuplan.planning.script.run_simulation import main as main_simulation

# Run the simulation loop (real-time visualization not yet supported, see next section for visualization)
main_simulation(cfg)

# Simple simulation folder for visualization in nuBoard
simple_simulation_folder = cfg.output_dir
# Out:
# Global seed set to 0
# 2026-07-03 09:44:03,800 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:20}  Building MultiMainCallback...
# 2026-07-03 09:44:03,909 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:35}  Building MultiMainCallback: 4...DONE!
# 2026-07-03 09:44:04,096 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2026-07-03 09:44:04,098 WARNING {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:135}  Ray is running, we will shut it down before starting again!
# 2026-07-03 09:44:05,816 INFO {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:78}  Starting ray local!
# 2026-07-03 09:44:07,832	INFO worker.py:1518 -- Started a local Ray instance.
# 2026-07-03 09:44:08,423 INFO {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2026-07-03 09:44:08,423 INFO {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 12
# Number of GPUs per node: 1
# Number of threads across all nodes: 12
# 2026-07-03 09:44:08,424 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2026-07-03 09:44:08,424 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:32}  Building experiment folders...
# 2026-07-03 09:44:08,424 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:35}
#
# 	Folder where all results are stored: /tmp/tutorial_nuplan_framework/simulation_simple_experiment/open_loop_boxes/2026.07.03.09.44.03
#
# 2026-07-03 09:44:08,426 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:70}  Building experiment folders...DONE!
# 2026-07-03 09:44:08,427 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:52}  Building AbstractCallback...
# 2026-07-03 09:44:08,427 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:68}  Building AbstractCallback: 0...DONE!
# 2026-07-03 09:44:08,427 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:47}  Building simulations...
# 2026-07-03 09:44:08,427 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:53}  Extracting scenarios...
# 2026-07-03 09:44:08,427 INFO {/root/nuplan-devkit/nuplan/common/utils/distributed_scenario_filter.py:83}  Building Scenarios in mode DistributedMode.SINGLE_NODE
# 2026-07-03 09:44:08,428 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2026-07-03 09:44:08,441 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2026-07-03 09:44:08,441 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2026-07-03 09:44:08,442 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# Ray objects: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:01<00:00,  7.71it/s]
# 2026-07-03 09:44:10,021 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:74}  Building metric engines...
# 2026-07-03 09:44:10,051 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:76}  Building metric engines...DONE
# 2026-07-03 09:44:10,052 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:80}  Building simulations from 31 scenarios...
# 2026-07-03 09:44:10,514 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:133}  Building simulations...DONE!
# 2026-07-03 09:44:10,523 INFO {/root/nuplan-devkit/nuplan/planning/script/run_simulation.py:78}  Running simulation...
# 2026-07-03 09:44:10,523 INFO {/root/nuplan-devkit/nuplan/planning/script/utils.py:138}  Executing runners...
# 2026-07-03 09:44:10,523 INFO {/root/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:82}  Starting 31 simulations using RayDistributed!
# Ray objects: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 31/31 [00:10<00:00,  2.98it/s]
# 2026-07-03 09:44:20,936 INFO {/root/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:127}  Number of successful simulations: 31
# 2026-07-03 09:44:20,936 INFO {/root/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:128}  Number of failed simulations: 0
# 2026-07-03 09:44:20,936 INFO {/root/nuplan-devkit/nuplan/planning/script/utils.py:147}  Finished executing runners!
# 2026-07-03 09:44:20,960 INFO {/root/nuplan-devkit/nuplan/planning/script/utils.py:74}  Saved runner reports to /tmp/tutorial_nuplan_framework/simulation_simple_experiment/open_loop_boxes/2026.07.03.09.44.03/runner_report.parquet
# 2026-07-03 09:44:20,961 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/time_callback.py:27}  Simulation duration: 00:00:17 [HH:MM:SS]
# 2026-07-03 09:44:21,124 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_file_callback.py:79}  Metric files integration: 00:00:00 [HH:MM:SS]
# 2026-07-03 09:44:21,167 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:58}  Running metric aggregator: open_loop_boxes_weighted_average
# 2026-07-03 09:44:21,183 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:69}  Metric aggregator: 00:00:00 [HH:MM:SS]
# Rendering histograms: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:01<00:00,  4.28it/s]
# 2026-07-03 09:44:23,431 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_summary_callback.py:344}  Metric summary: 00:00:02 [HH:MM:SS]
# 2026-07-03 09:44:23,431 INFO {/root/nuplan-devkit/nuplan/planning/script/run_simulation.py:80}  Finished running simulation!

# %% [markdown]
# ## Launch simulation (command line - alternative)

# %% [markdown]
# A simulation experiment can be launched alternatively with:
# ```
# $ python nuplan/planning/script/run_simulation.py \
#     +simulation=open_loop_boxes \
#     planner=simple_planner \
#     scenario_builder=nuplan_mini \
#     scenario_filter=all_scenarios \
#     scenario_filter.scenario_types="[near_multiple_vehicles, on_pickup_dropoff, starting_unprotected_cross_turn, high_magnitude_jerk]" \
#     scenario_filter.num_scenarios_per_type=10 \
# ```

# %% [markdown]
# ## Simulate a trained ML planner for comparison
#
# Using the same simulation settings as before, we can simulate a pretrained ML planner and compare the two.
#
# In this example you can take the model you trained earlier.

# %%
# Location of path with all simulation configs
CONFIG_PATH = '../nuplan/planning/script/config/simulation'
CONFIG_NAME = 'default_simulation'

# Get the checkpoint of the trained model
last_experiment = sorted(os.listdir(LOG_DIR))[-1]
train_experiment_dir = sorted(LOG_DIR.iterdir())[-1]
checkpoint = sorted((train_experiment_dir / 'checkpoints').iterdir())[-1]

MODEL_PATH = str(checkpoint).replace("=", "\=")

# Name of the experiment
EXPERIMENT = 'simulation_raster_experiment'

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    f'experiment_name={EXPERIMENT}',
    f'group={SAVE_DIR}',
    'planner=ml_planner',
    'model=raster_model',
    'planner.ml_planner.model_config=${model}',  # hydra notation to select model config
    f'planner.ml_planner.checkpoint_path={MODEL_PATH}',  # this path can be replaced by the checkpoint of the model trained in the previous section
    f'+simulation={CHALLENGE}',
    *DATASET_PARAMS,
])

# Run the simulation loop
main_simulation(cfg)

# ML_planner simulation folder for visualization in nuBoard (next section)
ml_planner_simulation_folder = cfg.output_dir
# Out:
# Global seed set to 0
# 2026-07-03 09:44:28,177 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:20}  Building MultiMainCallback...
# 2026-07-03 09:44:28,196 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/main_callback_builder.py:35}  Building MultiMainCallback: 4...DONE!
# 2026-07-03 09:44:28,382 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2026-07-03 09:44:28,382 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:19}  Building WorkerPool...
# 2026-07-03 09:44:28,383 WARNING {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:135}  Ray is running, we will shut it down before starting again!
# 2026-07-03 09:44:28,383 WARNING {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:135}  Ray is running, we will shut it down before starting again!
# 2026-07-03 09:44:30,044 INFO {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:78}  Starting ray local!
# 2026-07-03 09:44:30,044 INFO {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_ray.py:78}  Starting ray local!
# 2026-07-03 09:44:32,140	INFO worker.py:1518 -- Started a local Ray instance.
# 2026-07-03 09:44:32,741 INFO {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2026-07-03 09:44:32,741 INFO {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:101}  Worker: RayDistributed
# 2026-07-03 09:44:32,741 INFO {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 12
# Number of GPUs per node: 1
# Number of threads across all nodes: 12
# 2026-07-03 09:44:32,741 INFO {/root/nuplan-devkit/nuplan/planning/utils/multithreading/worker_pool.py:102}  Number of nodes: 1
# Number of CPUs per node: 12
# Number of GPUs per node: 1
# Number of threads across all nodes: 12
# 2026-07-03 09:44:32,741 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2026-07-03 09:44:32,741 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/worker_pool_builder.py:27}  Building WorkerPool...DONE!
# 2026-07-03 09:44:32,741 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:32}  Building experiment folders...
# 2026-07-03 09:44:32,741 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:32}  Building experiment folders...
# 2026-07-03 09:44:32,742 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:35}
#
# 	Folder where all results are stored: /tmp/tutorial_nuplan_framework/simulation_raster_experiment/open_loop_boxes/2026.07.03.09.44.28
#
# 2026-07-03 09:44:32,742 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:35}
#
# 	Folder where all results are stored: /tmp/tutorial_nuplan_framework/simulation_raster_experiment/open_loop_boxes/2026.07.03.09.44.28
#
# 2026-07-03 09:44:32,746 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:70}  Building experiment folders...DONE!
# 2026-07-03 09:44:32,746 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/folder_builder.py:70}  Building experiment folders...DONE!
# 2026-07-03 09:44:32,746 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:52}  Building AbstractCallback...
# 2026-07-03 09:44:32,746 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:52}  Building AbstractCallback...
# 2026-07-03 09:44:32,746 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:68}  Building AbstractCallback: 0...DONE!
# 2026-07-03 09:44:32,746 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_callback_builder.py:68}  Building AbstractCallback: 0...DONE!
# 2026-07-03 09:44:32,746 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:47}  Building simulations...
# 2026-07-03 09:44:32,746 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:47}  Building simulations...
# 2026-07-03 09:44:32,746 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:53}  Extracting scenarios...
# 2026-07-03 09:44:32,746 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:53}  Extracting scenarios...
# 2026-07-03 09:44:32,747 INFO {/root/nuplan-devkit/nuplan/common/utils/distributed_scenario_filter.py:83}  Building Scenarios in mode DistributedMode.SINGLE_NODE
# 2026-07-03 09:44:32,747 INFO {/root/nuplan-devkit/nuplan/common/utils/distributed_scenario_filter.py:83}  Building Scenarios in mode DistributedMode.SINGLE_NODE
# 2026-07-03 09:44:32,747 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2026-07-03 09:44:32,747 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2026-07-03 09:44:32,759 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2026-07-03 09:44:32,759 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2026-07-03 09:44:32,759 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2026-07-03 09:44:32,759 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:35}  Building ScenarioFilter...
# 2026-07-03 09:44:32,760 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# 2026-07-03 09:44:32,760 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_filter_builder.py:44}  Building ScenarioFilter...DONE!
# Ray objects: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:01<00:00,  6.54it/s]
# 2026-07-03 09:44:34,627 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:74}  Building metric engines...
# 2026-07-03 09:44:34,627 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:74}  Building metric engines...
# 2026-07-03 09:44:34,654 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:76}  Building metric engines...DONE
# 2026-07-03 09:44:34,654 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:76}  Building metric engines...DONE
# 2026-07-03 09:44:34,655 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:80}  Building simulations from 31 scenarios...
# 2026-07-03 09:44:34,655 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:80}  Building simulations from 31 scenarios...
# 2026-07-03 09:44:34,656 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:34,656 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:34,918 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:34,918 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:34,969 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:34,969 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:34,985 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:34,985 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:35,405 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:35,405 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:35,699 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:35,699 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:35,762 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:35,762 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:35,791 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:35,791 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:36,386 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:36,386 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:36,660 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:36,660 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:36,690 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:36,690 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:36,703 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:36,703 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:37,254 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:37,254 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:37,503 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:37,503 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:37,538 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:37,538 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:37,551 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:37,551 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:37,823 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:37,823 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:38,076 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:38,076 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:38,098 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:38,098 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:38,110 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:38,110 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:38,537 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:38,537 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:38,773 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:38,773 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:38,801 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:38,801 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:38,813 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:38,813 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:39,231 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:39,231 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:39,469 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:39,469 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:39,488 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:39,488 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:39,501 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:39,501 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:39,914 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:39,914 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:40,154 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:40,154 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:40,184 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:40,184 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:40,196 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:40,196 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:40,406 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:40,406 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:40,644 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:40,644 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:40,664 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:40,664 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:40,676 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:40,676 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:41,110 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:41,110 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:41,349 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:41,349 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:41,376 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:41,376 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:41,388 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:41,388 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:41,821 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:41,821 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:42,056 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:42,056 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:42,075 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:42,075 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:42,087 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:42,087 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:42,276 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:42,276 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:42,508 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:42,508 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:42,535 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:42,535 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:42,547 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:42,547 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:42,998 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:42,998 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:43,231 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:43,231 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:43,251 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:43,251 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:43,263 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:43,263 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:43,684 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:43,684 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:43,919 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:43,919 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:43,946 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:43,946 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:43,960 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:43,960 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:44,169 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:44,169 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:44,406 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:44,406 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:44,426 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:44,426 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:44,439 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:44,439 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:44,881 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:44,881 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:45,117 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:45,117 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:45,145 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:45,145 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:45,159 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:45,159 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:45,370 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:45,370 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:45,605 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:45,605 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:45,625 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:45,625 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:45,638 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:45,638 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:46,069 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:46,069 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:46,307 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:46,307 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:46,336 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:46,336 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:46,348 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:46,348 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:46,781 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:46,781 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:47,024 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:47,024 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:47,045 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:47,045 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:47,057 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:47,057 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:47,244 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:47,244 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:47,481 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:47,481 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:47,745 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:47,745 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:47,758 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:47,758 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:47,965 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:47,965 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:48,203 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:48,203 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:48,222 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:48,222 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:48,235 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:48,235 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:48,651 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:48,651 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:48,888 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:48,888 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:48,913 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:48,913 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:48,926 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:48,926 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:49,393 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:49,393 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:49,636 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:49,636 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:49,655 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:49,655 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:49,673 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:49,673 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:49,871 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:49,871 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:50,107 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:50,107 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:50,135 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:50,135 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:50,148 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:50,148 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:50,618 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:50,618 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:50,857 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:50,857 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:50,877 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:50,877 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:50,890 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:50,890 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:51,085 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:51,085 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:51,323 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:51,323 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:51,348 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:51,348 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:51,361 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:51,361 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:51,830 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:51,830 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:52,071 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:52,071 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:52,090 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:52,090 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:52,103 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:52,103 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:52,538 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:52,538 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:52,776 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:52,776 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:52,803 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# ...
# 2026-07-03 09:44:54,257 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:18}  Building TorchModuleWrapper...
# 2026-07-03 09:44:54,494 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:54,494 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:244}  Loading pretrained weights from url (https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth)
# 2026-07-03 09:44:54,514 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:54,514 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/timm/models/helpers.py:269}  Converted input conv conv1 pretrained weights from 3 to 4 channel(s)
# 2026-07-03 09:44:54,528 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:54,528 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/model_builder.py:21}  Building TorchModuleWrapper...DONE!
# 2026-07-03 09:44:54,984 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:133}  Building simulations...DONE!
# 2026-07-03 09:44:54,984 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/simulation_builder.py:133}  Building simulations...DONE!
# 2026-07-03 09:44:54,985 INFO {/root/nuplan-devkit/nuplan/planning/script/run_simulation.py:78}  Running simulation...
# 2026-07-03 09:44:54,985 INFO {/root/nuplan-devkit/nuplan/planning/script/run_simulation.py:78}  Running simulation...
# 2026-07-03 09:44:54,985 INFO {/root/nuplan-devkit/nuplan/planning/script/utils.py:138}  Executing runners...
# 2026-07-03 09:44:54,985 INFO {/root/nuplan-devkit/nuplan/planning/script/utils.py:138}  Executing runners...
# 2026-07-03 09:44:54,985 INFO {/root/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:82}  Starting 31 simulations using RayDistributed!
# 2026-07-03 09:44:54,985 INFO {/root/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:82}  Starting 31 simulations using RayDistributed!
# (wrapped_fn pid=7006) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/trio/_core/_multierror.py:511: RuntimeWarning: You seem to already have a custom sys.excepthook handler installed. I'll skip installing Trio's custom handler, but this means MultiErrors will not show full tracebacks.
# (wrapped_fn pid=7006)   warnings.warn(
# (wrapped_fn pid=7000) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/trio/_core/_multierror.py:511: RuntimeWarning: You seem to already have a custom sys.excepthook handler installed. I'll skip installing Trio's custom handler, but this means MultiErrors will not show full tracebacks.
# (wrapped_fn pid=7000)   warnings.warn(
# (wrapped_fn pid=7009) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/trio/_core/_multierror.py:511: RuntimeWarning: You seem to already have a custom sys.excepthook handler installed. I'll skip installing Trio's custom handler, but this means MultiErrors will not show full tracebacks.
# (wrapped_fn pid=7009)   warnings.warn(
# (wrapped_fn pid=7008) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/trio/_core/_multierror.py:511: RuntimeWarning: You seem to already have a custom sys.excepthook handler installed. I'll skip installing Trio's custom handler, but this means MultiErrors will not show full tracebacks.
# (wrapped_fn pid=7008)   warnings.warn(
# (wrapped_fn pid=7001) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/trio/_core/_multierror.py:511: RuntimeWarning: You seem to already have a custom sys.excepthook handler installed. I'll skip installing Trio's custom handler, but this means MultiErrors will not show full tracebacks.
# (wrapped_fn pid=7001)   warnings.warn(
# (wrapped_fn pid=7002) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/trio/_core/_multierror.py:511: RuntimeWarning: You seem to already have a custom sys.excepthook handler installed. I'll skip installing Trio's custom handler, but this means MultiErrors will not show full tracebacks.
# (wrapped_fn pid=7002)   warnings.warn(
# (wrapped_fn pid=7007) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/trio/_core/_multierror.py:511: RuntimeWarning: You seem to already have a custom sys.excepthook handler installed. I'll skip installing Trio's custom handler, but this means MultiErrors will not show full tracebacks.
# (wrapped_fn pid=7007)   warnings.warn(
# (wrapped_fn pid=7000) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=7000)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=6998) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/trio/_core/_multierror.py:511: RuntimeWarning: You seem to already have a custom sys.excepthook handler installed. I'll skip installing Trio's custom handler, but this means MultiErrors will not show full tracebacks.
# (wrapped_fn pid=6998)   warnings.warn(
# (wrapped_fn pid=7004) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/trio/_core/_multierror.py:511: RuntimeWarning: You seem to already have a custom sys.excepthook handler installed. I'll skip installing Trio's custom handler, but this means MultiErrors will not show full tracebacks.
# (wrapped_fn pid=7004)   warnings.warn(
# (wrapped_fn pid=7003) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/trio/_core/_multierror.py:511: RuntimeWarning: You seem to already have a custom sys.excepthook handler installed. I'll skip installing Trio's custom handler, but this means MultiErrors will not show full tracebacks.
# (wrapped_fn pid=7003)   warnings.warn(
# (wrapped_fn pid=7006) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=7006)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=7005) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/trio/_core/_multierror.py:511: RuntimeWarning: You seem to already have a custom sys.excepthook handler installed. I'll skip installing Trio's custom handler, but this means MultiErrors will not show full tracebacks.
# (wrapped_fn pid=7005)   warnings.warn(
# (wrapped_fn pid=6999) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/trio/_core/_multierror.py:511: RuntimeWarning: You seem to already have a custom sys.excepthook handler installed. I'll skip installing Trio's custom handler, but this means MultiErrors will not show full tracebacks.
# (wrapped_fn pid=6999)   warnings.warn(
# (wrapped_fn pid=7009) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=7009)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=7008) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=7008)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=7002) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=7002)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=7004) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=7004)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=7001) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=7001)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=7007) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=7007)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=7005) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=7005)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=6998) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=6998)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# (wrapped_fn pid=7003) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=7003)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Ray objects:   0%|                                                                                                                                                                                            | 0/31 [00:00<?, ?it/s](wrapped_fn pid=6999) /root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
# (wrapped_fn pid=6999)   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Ray objects: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 31/31 [02:02<00:00,  3.94s/it]
# 2026-07-03 09:47:02,401 INFO {/root/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:127}  Number of successful simulations: 31
# 2026-07-03 09:47:02,401 INFO {/root/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:127}  Number of successful simulations: 31
# 2026-07-03 09:47:02,401 INFO {/root/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:128}  Number of failed simulations: 0
# 2026-07-03 09:47:02,401 INFO {/root/nuplan-devkit/nuplan/planning/simulation/runner/executor.py:128}  Number of failed simulations: 0
# 2026-07-03 09:47:02,401 INFO {/root/nuplan-devkit/nuplan/planning/script/utils.py:147}  Finished executing runners!
# 2026-07-03 09:47:02,401 INFO {/root/nuplan-devkit/nuplan/planning/script/utils.py:147}  Finished executing runners!
# 2026-07-03 09:47:02,413 INFO {/root/nuplan-devkit/nuplan/planning/script/utils.py:74}  Saved runner reports to /tmp/tutorial_nuplan_framework/simulation_raster_experiment/open_loop_boxes/2026.07.03.09.44.28/runner_report.parquet
# 2026-07-03 09:47:02,413 INFO {/root/nuplan-devkit/nuplan/planning/script/utils.py:74}  Saved runner reports to /tmp/tutorial_nuplan_framework/simulation_raster_experiment/open_loop_boxes/2026.07.03.09.44.28/runner_report.parquet
# 2026-07-03 09:47:02,413 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/time_callback.py:27}  Simulation duration: 00:02:34 [HH:MM:SS]
# 2026-07-03 09:47:02,413 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/time_callback.py:27}  Simulation duration: 00:02:34 [HH:MM:SS]
# 2026-07-03 09:47:02,578 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_file_callback.py:79}  Metric files integration: 00:00:00 [HH:MM:SS]
# 2026-07-03 09:47:02,578 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_file_callback.py:79}  Metric files integration: 00:00:00 [HH:MM:SS]
# 2026-07-03 09:47:02,596 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:58}  Running metric aggregator: open_loop_boxes_weighted_average
# 2026-07-03 09:47:02,596 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:58}  Running metric aggregator: open_loop_boxes_weighted_average
# 2026-07-03 09:47:02,611 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:69}  Metric aggregator: 00:00:00 [HH:MM:SS]
# 2026-07-03 09:47:02,611 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_aggregator_callback.py:69}  Metric aggregator: 00:00:00 [HH:MM:SS]
# Rendering histograms: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:01<00:00,  4.22it/s]
# 2026-07-03 09:47:04,842 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_summary_callback.py:344}  Metric summary: 00:00:02 [HH:MM:SS]
# 2026-07-03 09:47:04,842 INFO {/root/nuplan-devkit/nuplan/planning/simulation/main_callback/metric_summary_callback.py:344}  Metric summary: 00:00:02 [HH:MM:SS]
# 2026-07-03 09:47:04,842 INFO {/root/nuplan-devkit/nuplan/planning/script/run_simulation.py:80}  Finished running simulation!
# 2026-07-03 09:47:04,842 INFO {/root/nuplan-devkit/nuplan/planning/script/run_simulation.py:80}  Finished running simulation!

# %% [markdown]
# # Visualizing metrics and scenarios <a name="dashboard"></a>

# %% [markdown]
# ## nuBoard summary
#
# Having trained and simulated planners across various scenarios and driving behaviors, it's time to evaluate them:
# * quantitatively, through common and scenario dependent metrics
# * qualitatively, through visualization of scenario progression
#
# ### nuBoard tabs
# To achieve that, nuBoard has 3 core evaluation tabs:
# 1. Overview - Scalar metrics summary of common and scenario metrics across the following categories:
#     * Ego dynamics
#     * Traffic violations
#     * Expert imitation
#     * Planning & navigation
#     * Scenario performance
# 2. Histograms - Histograms over metric statistics for more a granular peek inside each metric focusing on:
#     * Metric statistics (e.g. min, max, p90)
# 3. Scenarios - Low-level scenario visualizations:
#     * Time-series progression of a specific metric across a scenario
#     * Top-down visualization of the scenario across time for comparing predicted vs. expert trajectories
#
# In addition, there is a main configuration tab for selecting different simulation files for comparing planners/experiments.
#
# <br />
#
# **NOTE**: nuBoard is under heavy developement, overall functionality and aesthetics do not represent the final product!

# %% [markdown]
# ## Prepare the nuBoard config

# %%
# Location of path with all nuBoard configs
CONFIG_PATH = '../nuplan/planning/script/config/nuboard'
CONFIG_NAME = 'default_nuboard'

# Initialize configuration management system
hydra.core.global_hydra.GlobalHydra.instance().clear()  # reinitialize hydra if already initialized
hydra.initialize(config_path=CONFIG_PATH)

# Compose the configuration
cfg = hydra.compose(config_name=CONFIG_NAME, overrides=[
    'scenario_builder=nuplan_mini',  # set the database (same as simulation) used to fetch data for visualization
    f'simulation_path={[simple_simulation_folder, ml_planner_simulation_folder]}',  # nuboard file path(s), if left empty the user can open the file inside nuBoard
])

# %% [markdown]
# ## Launch nuBoard (open in new tab - recommended)

# %%
from nuplan.planning.script.run_nuboard import main as main_nuboard

# Run nuBoard
main_nuboard(cfg)
# Out:
# INFO:bokeh.server.server:Starting Bokeh server version 2.4.3 (running on Tornado 6.2)
# WARNING:bokeh.server.util:Host wildcard '*' will allow connections originating from multiple (or possibly all) hostnames or IPs. Use non-wildcard values to restrict access explicitly
# INFO:bokeh.server.tornado:User authentication hooks NOT provided (default user enabled)
# 2026-07-03 09:47:07,340 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2026-07-03 09:47:07,340 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:18}  Building AbstractScenarioBuilder...
# 2026-07-03 09:47:07,354 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2026-07-03 09:47:07,354 INFO {/root/nuplan-devkit/nuplan/planning/script/builders/scenario_building_builder.py:21}  Building AbstractScenarioBuilder...DONE!
# 2026-07-03 09:47:07,355 INFO {/root/nuplan-devkit/nuplan/planning/nuboard/nuboard.py:84}  Opening Bokeh application on http://localhost:5006/
# 2026-07-03 09:47:07,355 INFO {/root/nuplan-devkit/nuplan/planning/nuboard/nuboard.py:84}  Opening Bokeh application on http://localhost:5006/
# 2026-07-03 09:47:07,355 INFO {/root/nuplan-devkit/nuplan/planning/nuboard/nuboard.py:85}  Async rendering is set to: True
# 2026-07-03 09:47:07,355 INFO {/root/nuplan-devkit/nuplan/planning/nuboard/nuboard.py:85}  Async rendering is set to: True
# (node:7678) [DEP0169] DeprecationWarning: `url.parse()` behavior is not standardized and prone to errors that have security implications. Use the WHATWG URL API instead. CVEs are not issued for `url.parse()` vulnerabilities.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# 2026-07-03 09:47:08,191 INFO {/root/nuplan-devkit/nuplan/planning/nuboard/base/simulation_tile.py:172}  Minimum frame time=0.017 s
# 2026-07-03 09:47:08,191 INFO {/root/nuplan-devkit/nuplan/planning/nuboard/base/simulation_tile.py:172}  Minimum frame time=0.017 s
# 2026-07-03 09:47:08,210 INFO {/root/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:485}  Rending scenario plot takes 0.0010 seconds.
# 2026-07-03 09:47:08,210 INFO {/root/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:485}  Rending scenario plot takes 0.0010 seconds.
# 2026-07-03 09:47:08,335 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (127.0.0.1) 245.53ms
# 2026-07-03 09:47:08,335 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/tornado/web.py:2271}  200 GET / (127.0.0.1) 245.53ms
# INFO:tornado.access:200 GET / (127.0.0.1) 245.53ms
# INFO:tornado.access:304 GET /resource/motional_logo.png (127.0.0.1) 5.57ms
# 2026-07-03 09:47:08,531 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/tornado/web.py:2271}  304 GET /resource/motional_logo.png (127.0.0.1) 5.57ms
# 2026-07-03 09:47:08,531 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/tornado/web.py:2271}  304 GET /resource/motional_logo.png (127.0.0.1) 5.57ms
# WARNING:tornado.access:404 GET /favicon.ico (127.0.0.1) 0.53ms
# INFO:tornado.access:101 GET /ws (127.0.0.1) 0.76ms
# INFO:bokeh.server.views.ws:WebSocket connection opened
# INFO:bokeh.server.views.ws:ServerConnection created
# 2026-07-03 09:47:08,921 WARNING {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/tornado/web.py:2271}  404 GET /favicon.ico (127.0.0.1) 0.53ms
# 2026-07-03 09:47:08,921 WARNING {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/tornado/web.py:2271}  404 GET /favicon.ico (127.0.0.1) 0.53ms
# 2026-07-03 09:47:09,004 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (127.0.0.1) 0.76ms
# 2026-07-03 09:47:09,004 INFO {/root/miniconda3/envs/nuplan-pl138/lib/python3.9/site-packages/tornado/web.py:2271}  101 GET /ws (127.0.0.1) 0.76ms
# Rendering a scenario: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:00<00:00,  5.72it/s]
# 2026-07-03 09:47:32,294 INFO {/root/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:485}  Rending scenario plot takes 7.8458 seconds.
# 2026-07-03 09:47:32,294 INFO {/root/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:485}  Rending scenario plot takes 7.8458 seconds.
# 2026-07-03 10:49:21,245 INFO {/root/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:485}  Rending scenario plot takes 0.1105 seconds.
# 2026-07-03 10:49:21,245 INFO {/root/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:485}  Rending scenario plot takes 0.1105 seconds.
# 2026-07-03 10:49:26,166 INFO {/root/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:485}  Rending scenario plot takes 0.1075 seconds.
# 2026-07-03 10:49:26,166 INFO {/root/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:485}  Rending scenario plot takes 0.1075 seconds.
# 2026-07-03 10:49:31,823 INFO {/root/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:485}  Rending scenario plot takes 0.1087 seconds.
# 2026-07-03 10:49:31,823 INFO {/root/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:485}  Rending scenario plot takes 0.1087 seconds.
# 2026-07-03 10:49:36,580 INFO {/root/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:485}  Rending scenario plot takes 0.0797 seconds.
# 2026-07-03 10:49:36,580 INFO {/root/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:485}  Rending scenario plot takes 0.0797 seconds.
# 2026-07-03 10:49:41,329 INFO {/root/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:485}  Rending scenario plot takes 0.0160 seconds.
# 2026-07-03 10:49:41,329 INFO {/root/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:485}  Rending scenario plot takes 0.0160 seconds.
# 2026-07-03 10:49:45,886 INFO {/root/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:485}  Rending scenario plot takes 0.0833 seconds.
# 2026-07-03 10:49:45,886 INFO {/root/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:485}  Rending scenario plot takes 0.0833 seconds.
# 2026-07-03 10:52:41,476 INFO {/root/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:485}  Rending scenario plot takes 0.0156 seconds.
# 2026-07-03 10:52:41,476 INFO {/root/nuplan-devkit/nuplan/planning/nuboard/tabs/scenario_tab.py:485}  Rending scenario plot takes 0.0156 seconds.

# %% [markdown]
# ## Launch nuBoard (embedded within the notebook - alternative)

# %%
from bokeh.io import show, output_notebook
from nuplan.planning.script.run_nuboard import initialize_nuboard

# Make sure that the notebook working directory is "/notebooks" and that Jupyter was launched at the root of the repo
cfg.resource_prefix = '/notebooks/nuplan/planning/metrics/board/'  # pass CSS resources to the notebook

# Run the nuBoard
output_notebook()
nuboard = initialize_nuboard(cfg)
show(nuboard.main_page)

# %% [markdown]
# ## Launch nuBoard (command line - alternative)

# %% [markdown]
# nuBoard can be launched alternatively with:
# ```
# $ python nuplan/planning/script/run_nuboard.py
# ```
#
# Simulation files (.nuboard) can be selected under the configuration tab.
